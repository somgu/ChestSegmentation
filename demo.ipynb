# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

img = Image.open(r"C:\Users\user\Desktop\Project\ChestCT_GT\ChestCT_GT_Label\Chest_1_100000059_0.png")
gray_img = np.array(img)
plt.figure(1)
plt.imshow(gray_img, cmap='gray')
plt.show()

def threshold_labels(labels, threshold=1):
    unique_elements, counts_elements = np.unique(labels, return_counts=True)
    thr_elements = unique_elements[counts_elements>threshold]

    thr_labels = np.zeros_like(labels)

    cnt = 0
    for e in thr_elements:
        if e != 0:
            cnt += 1
            thr_labels[labels==e] = cnt
    return  thr_labels

res = threshold_labels(0.2)
plt.imshow(res, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21112/901275362.py in <module>
#      23
#      24 res = threshold_labels(0.2)
# ---> 25 plt.imshow(res, cmap='gray')
#      26 plt.show()
#
# ~\anaconda3\envs\Project\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\envs\Project\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\Project\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5607                               resample=resample, **kwargs)
#    5608
# -> 5609         im.set_data(X)
#    5610         im.set_alpha(alpha)
#    5611         if im.get_clip_path() is None:
#
# ~\anaconda3\envs\Project\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     707         if not (self._A.ndim == 2
#     708                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 709             raise TypeError("Invalid shape {} for image data"
#     710                             .format(self._A.shape))
#     711
#
# TypeError: Invalid shape () for image data
